# %%
import pandas as pd
train_df = pd.read_csv("ExtraCredit_Train.csv")
test_df = pd.read_csv("ExtraCredit_Test.csv")

# %%
import cv2

# %%
for i,j in zip(train_df["file_name"],train_df["annotation"]:
# Out:
#     file_name  annotation      hours  air_temperature  humidity  pressure  \
# 0  000006.jpg           0   7.000000            24.84  0.017546   99748.1
# 1  000016.jpg           0  11.516667            32.42  0.018943   99356.9
# 2  000032.jpg           0  20.016667            30.20  0.019103   99171.1
# 3  000097.jpg           4  10.800000            25.54  0.012345  100449.0
# 4  000104.jpg           0   8.750000            26.60  0.017723   99751.7
#
#    zonal_wind_speed  meridional_wind_speed  longwave_radiation  \
# 0              2.90                   3.28              401.18
# 1              3.08                   2.50              458.45
# 2              1.07                   3.52              434.54
# 3              1.28                  -0.53              401.86
# 4              3.33                   2.98              401.19
#
#    convective_precipitation  potential_energy  potential_evaporation  \
# 0                       0.0           602.624                 0.0265
# 1                       0.0          2086.400                 0.8650
# 2                       0.0          1760.380                 0.0595
# 3                       0.0             0.000                 0.3351
# 4                       0.0          1033.020                 0.4682
#
#    precipitation  shortwave_radiation
# 0            0.0              216.280
# 1            0.0              791.133
# 2            0.0                0.000
# 3            0.0              619.795
# 4            0.0              387.584
